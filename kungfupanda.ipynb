# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, ARRAY, Date, Float, text, select
import pandas as pd



df = pd.read_csv("/Users/Vengeance/Documents/GitHub/earthquake-analysis-japan/JAPAN_DATASET.csv")

# %%
df.head()
# Out:
#                        time latitude  longitude depth        mag  \
# 0  2025-09-15T12:45:30.123Z   38.322   142.3690  35.0        5.1
# 1  2025-09-16T08:22:05.456Z  36.2048   138.2529   NaN        NaN
# 2    Sep 17, 2025, 14:10:05  43.0618   141.3545  10.2        4.8
# 3  2025-09-18T23:11:55.000Z  33.5904   130.4017  12.0  four.nine
# 4  2025-09-19T05:00:00.000Z  35.6895   139.6917  -999        5.5
#
#                              place     status        notes
# 0  off east coast of Honshu, Japan   reviewed          NaN
# 1               near Nagano, Japan  automatic  Minor shock
# 2           Hokkaido, Japan region   reviewed          NaN
# 3                   Fukuoka, Japan   reviewed          NaN
# 4                    Tokyo, Japan    reviewed  Data error?

# %%
engine = create_engine('sqlite:///mydb.db')
connection = engine.connect()
metadata = MetaData()

earthquakes = Table('Earthquakes',
                    metadata,
                    Column('id', Integer, primary_key=True),
                    Column('time', Date),#not sure yet
                    Column('coordination', String),#not sure yet
                    Column('depth', Float),
                    Column('magnitude', Float),
                    Column('region',String),
                    Column('source', String),
                    )
df.to_sql(
    name="Earthquakes",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=1000
)   

# def insert_data(time, coordination, depth, magnitude, region, source):
#     earthquakes.insert().values(time= time, coordination= coordination, depth= depth, magnitude= magnitude, region= region, source= source)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlalchemy/engine/default.py:948, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     947 def do_executemany(self, cursor, statement, parameters, context=None):
# ...

# %%
count = connection.execute(text("SELECT COUNT(*) FROM Earthquakes;")).scalar()
print(f"Number of rows: {count}")
# Out:
# Number of rows: 180

# %%
df.head()
# Out:
#                        time latitude  longitude depth        mag  \
# 0  2025-09-15T12:45:30.123Z   38.322   142.3690  35.0        5.1
# 1  2025-09-16T08:22:05.456Z  36.2048   138.2529   NaN        NaN
# 2    Sep 17, 2025, 14:10:05  43.0618   141.3545  10.2        4.8
# 3  2025-09-18T23:11:55.000Z  33.5904   130.4017  12.0  four.nine
# 4  2025-09-19T05:00:00.000Z  35.6895   139.6917  -999        5.5
#
#                              place     status        notes
# 0  off east coast of Honshu, Japan   reviewed          NaN
# 1               near Nagano, Japan  automatic  Minor shock
# 2           Hokkaido, Japan region   reviewed          NaN
# 3                   Fukuoka, Japan   reviewed          NaN
# 4                    Tokyo, Japan    reviewed  Data error?

# %%
df['coordination'] = df.apply(lambda x: f"[{x.latitude}, {x.longitude}]", axis=1)
df.head()
# Out:
#                        time latitude  longitude depth        mag  \
# 0  2025-09-15T12:45:30.123Z   38.322   142.3690  35.0        5.1
# 1  2025-09-16T08:22:05.456Z  36.2048   138.2529   NaN        NaN
# 2    Sep 17, 2025, 14:10:05  43.0618   141.3545  10.2        4.8
# 3  2025-09-18T23:11:55.000Z  33.5904   130.4017  12.0  four.nine
# 4  2025-09-19T05:00:00.000Z  35.6895   139.6917  -999        5.5
#
#                              place     status        notes  \
# 0  off east coast of Honshu, Japan   reviewed          NaN
# 1               near Nagano, Japan  automatic  Minor shock
# 2           Hokkaido, Japan region   reviewed          NaN
# 3                   Fukuoka, Japan   reviewed          NaN
# 4                    Tokyo, Japan    reviewed  Data error?
#
#           coordination
# 0    [38.322, 142.369]
# 1  [36.2048, 138.2529]
# 2  [43.0618, 141.3545]
# 3  [33.5904, 130.4017]
# 4  [35.6895, 139.6917]

# %%
result = connection.execute(text("SELECT * FROM Earthquakes LIMIT 5;")).fetchall()
for row in result:
    print(row)
# Out:
# ('2025-09-15T12:45:30.123Z', '38.322', 142.369, '35.0', '5.1', 'off east coast of Honshu, Japan', 'reviewed', None)
# ('2025-09-16T08:22:05.456Z', '36.2048', 138.2529, None, None, 'near Nagano, Japan', 'automatic', 'Minor shock')
# ('Sep 17, 2025, 14:10:05', '43.0618', 141.3545, '10.2', '4.8', 'Hokkaido, Japan region', 'reviewed', None)
# ('2025-09-18T23:11:55.000Z', '33.5904', 130.4017, '12.0', 'four.nine', 'Fukuoka, Japan', 'reviewed', None)
# ('2025-09-19T05:00:00.000Z', '35.6895', 139.6917, '-999', '5.5', ' Tokyo, Japan ', 'reviewed', 'Data error?')
